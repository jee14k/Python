# %%
x = range(1,11)
for i in x:
    y=i**2 + 2*i + 1
    print('x={0} y={1}'.format(i,y))
# Out:
# x=1 y=4
# x=2 y=9
# x=3 y=16
# x=4 y=25
# x=5 y=36
# x=6 y=49
# x=7 y=64
# x=8 y=81
# x=9 y=100
# x=10 y=121

# %%
import matplotlib.pyplot as plt
def draw_graph(x,y):
    plt.plot(x,y)
    plt.show()
    
x=range(-100,100,20)
y=[]
for i in x:
    y.append(i**2 + 2*i +1)
draw_graph(x,y)
